# %%
# please ensure python version is 3.12

# %%
# !pip install pandas openpyxl langchain langchain-classic langchain-text-splitters langchain-huggingface langchain-community chromadb openai sentence-transformers tiktoken huggingface_hub
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: langchain in /opt/anaconda3/lib/python3.13/site-packages (1.0.8)
# Requirement already satisfied: langchain-text-splitters in /opt/anaconda3/lib/python3.13/site-packages (1.0.0)
# ERROR: Could not find a version that satisfies the requirement langchain-huggingface-hub (from versions: none)
# ERROR: No matching distribution found for langchain-huggingface-hub

# %%
# uncomment and run the below commands in case of module import errors due to change in python version
# please ensure python version is 3.12 / python kernel is set to 3.12 in case of jupyter notebook
import sys
# !{sys.executable} -m pip install pandas openpyxl langchain langchain-classic langchain-text-splitters langchain-huggingface langchain-community chromadb openai sentence-transformers tiktoken huggingface_hub
# Out:
# Requirement already satisfied: pandas in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: openpyxl in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: langchain in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (1.0.8)
# Requirement already satisfied: langchain-classic in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: langchain-text-splitters in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: langchain-huggingface in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: langchain-community in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: chromadb in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (1.3.5)
# Requirement already satisfied: openai in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (2.8.1)
# Requirement already satisfied: sentence-transformers in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (5.1.2)
# Requirement already satisfied: tiktoken in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: huggingface_hub in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (0.36.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain) (1.0.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (0.4.44)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-classic) (2.0.44)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.3.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from huggingface_hub) (2025.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: build>=1.0.3 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: Pillow in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: pyproject_hooks in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.29.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.1)
# Requirement already satisfied: sympy in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: setuptools in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/shreyaaggarwal/rag_env/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
import pandas as pd
import os
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_classic.vectorstores import Chroma
from langchain_classic.chains import RetrievalQA
from langchain_classic.llms import HuggingFaceHub
from langchain_classic.schema import Document

# %%
# Data paths
DATA_DIR = "../../data/"

ecli_path = os.path.join(DATA_DIR, "DATA ecli_nummers juni 2025 v1 (version 1).xlsx")
letters_path = os.path.join(DATA_DIR, "Dataset Advice letters on objections towing of bicycles.xlsx")

# %%
# Load Excel files
df_ecli = pd.read_excel(ecli_path)
df_letters = pd.read_excel(letters_path)

# Select only the text columns we need
ecli_texts = df_ecli['ecli_tekst'].astype(str).tolist()
letters_texts = df_letters['geanonimiseerd_doc_inhoud'].astype(str).tolist()

# Quick sanity check
print("Number of ECLI cases:", len(ecli_texts))
print("Number of advice letters:", len(letters_texts))
print("Sample ECLI text:", ecli_texts[0][:200])
print("Sample advice letter text:", letters_texts[0][:200])
# Out:
# Number of ECLI cases: 2447
# Number of advice letters: 567
# Sample ECLI text:
# RvdW 2014/158
#
#
#
#
# http://deeplink.rechtspraak.nl/uitspraak?id=ECLI:NL:HR:2014:39
# text/html
# public
# 2014-01-08T10:14:07
# 2014-01-08
# Raad voor de Rechtspraak
# nl
# ECLI:NL:HR:2014:39 Hoge Raad , 07-01-2014
# Sample advice letter text: Advies van de bezwaarschriftencommissie Juridisch Bureau
#
# Aan                Het college van burgemeester en wethouders van Amsterdam
# Zaaknummer         JB.19.012268.001
# Datum              2 december

# %%
# Wrap ECLI cases as Documents
# TODO: add more metadata if reqd
case_docs = [
    Document(page_content=text, metadata={"source": "case", "ecli_nummer": df_ecli.loc[i, "ecli_nummer"]})
    for i, text in enumerate(ecli_texts)
]

# Wrap Advice letters as Documents
# TODO: add more metadata if reqd
advice_docs = [
    Document(page_content=text, metadata={
        "source": "advice",
        "zaaknummer": df_letters.loc[i, "Octopus zaaknummer"],
        "onderwerp": df_letters.loc[i, "Onderwerp"]
    })
    for i, text in enumerate(letters_texts)
]

# Combine all documents
all_docs = case_docs + advice_docs

print(f"Total documents prepared: {len(all_docs)}")
print("Sample document metadata:", all_docs[0].metadata)
print("Sample document text (first 200 chars):", all_docs[0].page_content[:200])
# Out:
# Total documents prepared: 3014
# Sample document metadata: {'source': 'case', 'ecli_nummer': 'ECLI:NL:HR:2014:39'}
# Sample document text (first 200 chars):
# RvdW 2014/158
#
#
#
#
# http://deeplink.rechtspraak.nl/uitspraak?id=ECLI:NL:HR:2014:39
# text/html
# public
# 2014-01-08T10:14:07
# 2014-01-08
# Raad voor de Rechtspraak
# nl
# ECLI:NL:HR:2014:39 Hoge Raad , 07-01-2014

# %%
# Create a text splitter
# chunk_size = maximum number of characters per chunk
# chunk_overlap = number of characters overlapping between chunks to preserve context
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=150
)

# Split all documents (ECLI cases + Advice letters) into smaller chunks
# Splitting preserves metadata for each chunk
split_docs = text_splitter.split_documents(all_docs)

# Print original number of documents
print("Original number of documents:", len(all_docs))

# Print number of chunks created to verify
print("Number of chunks created after splitting:", len(split_docs))

# Optional: print a sample chunk and its metadata for verification
print("\nSample chunk text (first 200 chars):")
print(split_docs[0].page_content[:200])

print("\nSample chunk metadata:")
print(split_docs[0].metadata)
# Out:
# Original number of documents: 3014
# Number of chunks created after splitting: 83904
#
# Sample chunk text (first 200 chars):
# RvdW 2014/158
#
#
#
#
# http://deeplink.rechtspraak.nl/uitspraak?id=ECLI:NL:HR:2014:39
# text/html
# public
# 2014-01-08T10:14:07
# 2014-01-08
# Raad voor de Rechtspraak
# nl
# ECLI:NL:HR:2014:39 Hoge Raad , 07-01-2014 /
#
# Sample chunk metadata:
# {'source': 'case', 'ecli_nummer': 'ECLI:NL:HR:2014:39'}

# %%
# Create Embeddings
# Purpose: Convert each text chunk into a numeric vector (embedding) that captures its semantic meaning
# These embeddings will be stored in a vector store (Chroma) for similarity search

def create_embeddings(split_docs, model_name):
    """
    Create an embeddings object using the model given and test it on the first document chunk.
    """
    print("Initializing embeddings model...")
    print(f"Using model: {model_name}")

    # Initialize embeddings
    embeddings = HuggingFaceEmbeddings(model_name=model_name)

    # Test on the first chunk to confirm model works
    print("\nTesting embedding on first chunk...")
    sample_text = split_docs[0].page_content
    test_embedding = embeddings.embed_documents([sample_text])

    print("Embedding created successfully!")
    print("Embedding vector length:", len(test_embedding[0]))
    print("First 5 values:", test_embedding[0][:5])

    return embeddings

# %%
# Note: For Dutch legal text, possibly change later to another and test, eg: 'pdelobelle/robbert-v2-dutch-base'
embedding_model = "sentence-transformers/all-mpnet-base-v2"

embeddings = create_embeddings(
    split_docs,
    model_name=embedding_model
)
# Out:
# Initializing embeddings model...
# Using model: sentence-transformers/all-mpnet-base-v2
#
# Testing embedding on first chunk...
# Embedding created successfully!
# Embedding vector length: 768
# First 5 values: [0.04207202419638634, -0.03519180789589882, 0.020371224731206894, 0.041567977517843246, -0.09661170095205307]

# %%
# Directory to persist Chroma database
PERSIST_DIR = "../resources/chroma_db"

# %%
# Create Chroma vector store from split documents
# Purpose: Store embeddings of all document chunks for fast similarity search
# Also preserves metadata (like source, case number) for context during retrieval

def create_vector_store(documents, persist_directory=PERSIST_DIR):
    """Create a new Chroma vector store."""
    start = time.time()
    
    # Create directory if it does not exist
    os.makedirs(persist_directory, exist_ok=True)
    
    vector_store = Chroma.from_documents(
        documents=documents,
        embedding=embeddings,
        collection_name="legal_rag",
        persist_directory=persist_directory
    )

    # Persist the vector store to disk
    vector_store.persist()

    print("Chroma vector store created and persisted successfully!")
    print("Number of documents stored in vector store:", vector_store._collection.count())
    print(f"Vector store saved at: {persist_directory}")
    print(f"Time taken: {time.time() - start:.2f} seconds")

    return vector_store

# %%
def load_vector_store(persist_directory=PERSIST_DIR):
    """Load an existing Chroma vector store."""
    vector_store = Chroma(
        collection_name="legal_rag",
        embedding_function=embeddings,
        persist_directory=persist_directory
    )
    print("Loaded existing Chroma DB.")
    return vector_store

# %%
def update_vector_store(new_documents, persist_directory=PERSIST_DIR):
    """Add new documents into an existing Chroma store."""
    start = time.time()

    vector_store = load_vector_db(persist_directory)
    
    vector_store.add_documents(new_documents)

    # Persist the vector store to disk
    vector_store.persist()

    print("Chroma vector store updated with new documents!")
    print("Total number of documents stored in vector store:", vector_store._collection.count())
    print(f"Update time: {time.time() - start:.2f} seconds")

    return vector_store

# %%
# sample usage
create_vector_store(split_docs)
store = load_vector_store()
#update_vector_store(split_docs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 2
#       1 # sample usage
# ----> 2 create_vector_store(split_docs)
#       3 store = load_vector_store()
#       4 #update_vector_store(split_docs)
#
# Cell In[47], line 12, in create_vector_store(documents, persist_directory)
#       9 # Create directory if it does not exist
#      10 os.makedirs(persist_directory, exist_ok=True)
# ---> 12 vector_store = Chroma.from_documents(
#      13     documents=documents,
#      14     embedding=embeddings,
#      15     collection_name="legal_rag",
#      16     persist_directory=persist_directory
#      17 )
#      19 # Persist the vector store to disk
#      20 vector_store.persist()
#
# File ~/rag_env/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
#     893     persist_directory=persist_directory,
#     894     client_settings=client_settings,
#     895     client=client,
#     896     collection_metadata=collection_metadata,
#     897     **kwargs,
#     898 )
#
# File ~/rag_env/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py:843, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     835     from chromadb.utils.batch_utils import create_batches
#     837     for batch in create_batches(
#     838         api=chroma_collection._client,
#     839         ids=ids,
#     840         metadatas=metadatas,
#     841         documents=texts,
#     842     ):
# --> 843         chroma_collection.add_texts(
#     844             texts=batch[3] if batch[3] else [],
#     845             metadatas=batch[2] if batch[2] else None,
#     846             ids=batch[0],
#     847         )
#     848 else:
#     849     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File ~/rag_env/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py:277, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     275 texts = list(texts)
#     276 if self._embedding_function is not None:
# --> 277     embeddings = self._embedding_function.embed_documents(texts)
#     278 if metadatas:
#     279     # fill metadatas with empty dicts if somebody
#     280     # did not specify metadata for all texts
#     281     length_diff = len(texts) - len(metadatas)
#
# File ~/rag_env/lib/python3.12/site-packages/langchain_huggingface/embeddings/huggingface.py:155, in HuggingFaceEmbeddings.embed_documents(self, texts)
#     145 def embed_documents(self, texts: list[str]) -> list[list[float]]:
#     146     """Compute doc embeddings using a HuggingFace transformer model.
#     147
#     148     Args:
#    (...)    153
#     154     """
# --> 155     return self._embed(texts, self.encode_kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/langchain_huggingface/embeddings/huggingface.py:130, in HuggingFaceEmbeddings._embed(self, texts, encode_kwargs)
#     128     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     129 else:
# --> 130     embeddings = self._client.encode(
#     131         texts,
#     132         show_progress_bar=self.show_progress,
#     133         **encode_kwargs,
#     134     )
#     136 if isinstance(embeddings, list):
#     137     msg = (
#     138         "Expected embeddings to be a Tensor or a numpy array, "
#     139         "got a list instead."
#     140     )
#
# File ~/rag_env/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File ~/rag_env/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/rag_env/lib/python3.12/site-packages/sentence_transformers/models/Transformer.py:261, in Transformer.forward(self, features, **kwargs)
#     238 """
#     239 Forward pass through the transformer model.
#     240
#    (...)    257         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     258 """
#     259 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 261 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     262 token_embeddings = outputs[0]
#     263 features["token_embeddings"] = token_embeddings
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/rag_env/lib/python3.12/site-packages/transformers/models/mpnet/modeling_mpnet.py:486, in MPNetModel.forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     484 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     485 embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 486 encoder_outputs = self.encoder(
#     487     embedding_output,
#     488     attention_mask=extended_attention_mask,
#     489     head_mask=head_mask,
#     490     output_attentions=output_attentions,
#     491     output_hidden_states=output_hidden_states,
#     492     return_dict=return_dict,
#     493 )
#     494 sequence_output = encoder_outputs[0]
#     495 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/rag_env/lib/python3.12/site-packages/transformers/models/mpnet/modeling_mpnet.py:338, in MPNetEncoder.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     335 if output_hidden_states:
#     336     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 338 layer_outputs = layer_module(
#     339     hidden_states,
#     340     attention_mask,
#     341     head_mask[i],
#     342     position_bias,
#     343     output_attentions=output_attentions,
#     344     **kwargs,
#     345 )
#     346 hidden_states = layer_outputs[0]
#     348 if output_attentions:
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/rag_env/lib/python3.12/site-packages/transformers/models/mpnet/modeling_mpnet.py:297, in MPNetLayer.forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     288 def forward(
#     289     self,
#     290     hidden_states,
#    (...)    295     **kwargs,
#     296 ):
# --> 297     self_attention_outputs = self.attention(
#     298         hidden_states,
#     299         attention_mask,
#     300         head_mask,
#     301         position_bias=position_bias,
#     302         output_attentions=output_attentions,
#     303     )
#     304     attention_output = self_attention_outputs[0]
#     305     outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/rag_env/lib/python3.12/site-packages/transformers/models/mpnet/modeling_mpnet.py:238, in MPNetAttention.forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     229 def forward(
#     230     self,
#     231     hidden_states,
#    (...)    236     **kwargs,
#     237 ):
# --> 238     self_outputs = self.attn(
#     239         hidden_states,
#     240         attention_mask,
#     241         head_mask,
#     242         position_bias,
#     243         output_attentions=output_attentions,
#     244     )
#     245     attention_output = self.LayerNorm(self.dropout(self_outputs[0]) + hidden_states)
#     246     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/rag_env/lib/python3.12/site-packages/transformers/models/mpnet/modeling_mpnet.py:168, in MPNetSelfAttention.forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     157 q = (
#     158     self.q(hidden_states)
#     159     .view(batch_size, -1, self.num_attention_heads, self.attention_head_size)
#     160     .transpose(1, 2)
#     161 )
#     162 k = (
#     163     self.k(hidden_states)
#     164     .view(batch_size, -1, self.num_attention_heads, self.attention_head_size)
#     165     .transpose(1, 2)
#     166 )
#     167 v = (
# --> 168     self.v(hidden_states)
#     169     .view(batch_size, -1, self.num_attention_heads, self.attention_head_size)
#     170     .transpose(1, 2)
#     171 )
#     173 # Take the dot product between "query" and "key" to get the raw attention scores.
#     174 attention_scores = torch.matmul(q, k.transpose(-1, -2))
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/rag_env/lib/python3.12/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
